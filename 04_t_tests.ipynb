# %% [markdown]
# # $t$-Tests
#
# <img src="https://imgs.xkcd.com/comics/correlation_2x.png" alt="xkcd" width="500"/>

# %%
# Numerical arrays.
import numpy as np

# Statistical functions.
import scipy.stats as stats

# Data frames.
import pandas as pd

# Plotting.
import matplotlib.pyplot as plt

# Statistical plots.
import seaborn as sns

# %% [markdown]
# ## Normal Data
#
# [numpy.random.normal](https://numpy.org/doc/2.0/reference/random/generated/numpy.random.normal.html)

# %%
# Group A.
group_a = np.random.normal(5, 2, 30)

# Group B.
group_b = np.random.normal(5, 2, 30)

# Show.
group_a, group_b
# Out:
# (array([ 2.10834107,  5.36111612,  4.88240584,  4.42203842,  6.45794753,
#          5.94999671,  4.73349231,  5.85986532,  5.1204361 ,  0.78542937,
#          4.39004129,  7.54759977,  4.46688095,  5.33941848,  3.84483758,
#          6.09018009,  4.22519625,  5.51209902,  4.41791978, -0.66586555,
#          7.66016317,  2.50924108,  2.96212929,  6.29658112,  3.12004529,
#          6.46475921,  6.35908461,  4.39089747,  7.26807636,  5.30331331]),
#  array([1.76890948, 4.94258829, 4.54307641, 5.21520761, 5.37573865,
#         7.54504622, 5.81172945, 2.21876408, 5.62620002, 4.78798154,
#         1.59961154, 4.61668276, 3.35067057, 3.25870645, 4.73210105,
#         2.06310906, 8.34106628, 7.50676635, 4.29958752, 3.07408294,
#         8.09093201, 7.38065606, 5.10176605, 2.85656895, 8.33010732,
#         2.62536064, 7.01914198, 7.13786638, 3.83524355, 4.31274822]))

# %%
# Create an empty data frame.
fig, ax = plt.subplots(figsize=(10, 5))

# Create histogram.
ax.hist(group_a, bins=range(10), color='blue', alpha=0.5, label='Group A')

# Create histogram.
ax.hist(group_b, bins=range(10), color='green', alpha=0.5, label='Group B');

# %%
# Create a strip plot.
sns.stripplot(data=[group_a, group_b]);

# %%
# Box plot.
sns.boxplot(data=[group_a, group_b]);

# %% [markdown]
# ## Independent Samples $t$-Test
#
# [scipy.stats.
# ttest_ind](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html#ttest-ind)
#
# **Null Hypothesis:** the population means are equal.

# %%
# Perform a t-test.
stats.ttest_ind(group_a, group_b)
# Out:
# TtestResult(statistic=-0.27426996344353494, pvalue=0.7848516697747219, df=58.0)

# %% [markdown]
# ## End
